# %%
import pyodbc
server = 'sqlserver.dmst.aueb.gr'
database = 'DB68'
cnxn_str = 'DRIVER={SQL Server};'\
           'SERVER='+server+';DATABASE='+database+';'\
           'UID=G568;pwd=39_g59030'
cnxn = pyodbc.connect(cnxn_str)
cursor = cnxn.cursor()

print('Δώστε κωδικό πελάτη')
customercode=input()

cursor.execute(
                'DELETE FROM ΠΕΛΑΤΕΣ WHERE ΚΩΔΙΚΟΣ={}'.format(customercode))
cnxn.commit()
rows_affected = cursor.rowcount

print(f'{rows_affected} row(s) deleted.')

help(format)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e3e9c7f4f887> in <cell line: 1>()
# ----> 1 import pyodbc
#       2 server = 'sqlserver.dmst.aueb.gr'
#       3 database = 'DB68'
#       4 cnxn_str = 'DRIVER={SQL Server};'\
#       5            'SERVER='+server+';DATABASE='+database+';'\
#
# ModuleNotFoundError: No module named 'pyodbc'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
help(format)
# Out:
# Help on built-in function format in module builtins:
#
# format(value, format_spec='', /)
#     Return value.__format__(format_spec)
#
#     format_spec defaults to the empty string.
#     See the Format Specification Mini-Language section of help('FORMATTING') for
#     details.
